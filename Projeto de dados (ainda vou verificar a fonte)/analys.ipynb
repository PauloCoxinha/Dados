# %%
import pandas as pd 

from push import df_bronze

# %%
df_silver = df_bronze.copy()

colunas_de_preco = ["preco_menor", "preco_comum", "preco_maior"]

for coluna in colunas_de_preco:
    df_silver[coluna] = df_silver[coluna].str.replace(r'[^\d,]', '', regex=True)

    df_silver[coluna] = df_silver[coluna].str.replace(',', '.')

    df_silver[coluna] = pd.to_numeric(df_silver[coluna], errors='coerce')

df_silver['produtos'] = df_silver['produtos'].str.upper()

print("\n--- Tipos de dados na camada Silver ---")
print(df_silver.dtypes)

print("\n--- Amostra dos dados limpos ---")
print(df_silver.head())

df_silver.to_parquet('silver_ceagesp.parquet', index=False)
# Out:
# --- Tipos de dados na camada Silver ---
# produtos             str
# classificacao        str
# unidade              str
# preco_menor      float64
# preco_comum      float64
# preco_maior      float64
# dtype: object
#
# --- Amostra dos dados limpos ---
#                       produtos  classificacao   unidade  preco_menor  \
# 0                      PRODUTO  Classificação  Uni/Peso          NaN
# 1  ABACATE AVOCADO/HASS/FUERTE              A        KG         6.89
# 2                ABACATE BREDA   BOCA 08 A 11        KG         4.71
# 3                ABACATE BREDA   BOCA 12 A 15        KG         3.70
# 4              ABACATE FORTUNA   BOCA 08 A 11        KG         3.89
#
#    preco_comum  preco_maior
# 0          NaN          NaN
# 1         8.37         9.85
# 2         5.14         5.58
# 3         4.19         4.71
# 4         4.17         4.44
# ---------------------------------------------------------------------------
# ArrowKeyError                             Traceback (most recent call last)
# Cell In[7], line 20
#      16
#      17 print("\n--- Amostra dos dados limpos ---")
#      18 print(df_silver.head())
#      19
# ---> 20 df_silver.to_parquet('silver_ceagesp.parquet', index=False)
#
# File f:\projetos\Dados\Projeto de dados (ainda vou verificar a fonte)\.venv\Lib\site-packages\pandas\core\frame.py:3135, in DataFrame.to_parquet(self, path, engine, compression, index, partition_cols, storage_options, filesystem, **kwargs)
#    3131         >>> content = f.read()
#    3132         """
#    3133         from pandas.io.parquet import to_parquet
#    3134
# -> 3135         return to_parquet(
#    3136             self,
#    3137             path,
#    3138             engine,
#
# File f:\projetos\Dados\Projeto de dados (ainda vou verificar a fonte)\.venv\Lib\site-packages\pandas\io\parquet.py:486, in to_parquet(df, path, engine, compression, index, storage_options, partition_cols, filesystem, **kwargs)
#     484 if isinstance(partition_cols, str):
#     485     partition_cols = [partition_cols]
# --> 486 impl = get_engine(engine)
#     488 path_or_buf: FilePath | WriteBuffer[bytes] = io.BytesIO() if path is None else path
#     490 impl.write(
#     491     df,
#     492     path_or_buf,
#    (...)    498     **kwargs,
#     499 )
#
# File f:\projetos\Dados\Projeto de dados (ainda vou verificar a fonte)\.venv\Lib\site-packages\pandas\io\parquet.py:64, in get_engine(engine)
#      62 for engine_class in engine_classes:
#      63     try:
# ---> 64         return engine_class()
#      65     except ImportError as err:
#      66         error_msgs += "\n - " + str(err)
#
# File f:\projetos\Dados\Projeto de dados (ainda vou verificar a fonte)\.venv\Lib\site-packages\pandas\io\parquet.py:170, in PyArrowImpl.__init__(self)
#     167 import pyarrow.parquet
#     169 # import utils to register the pyarrow extension types
# --> 170 import pandas.core.arrays.arrow.extension_types  # pyright: ignore[reportUnusedImport] # noqa: F401
#     172 self.api = pyarrow
#
# File f:\projetos\Dados\Projeto de dados (ainda vou verificar a fonte)\.venv\Lib\site-packages\pandas\core\arrays\arrow\extension_types.py:59
#      57 # register the type with a dummy instance
#      58 _period_type = ArrowPeriodType("D")
# ---> 59 pyarrow.register_extension_type(_period_type)
#      62 class ArrowIntervalType(pyarrow.ExtensionType):
#      63     def __init__(self, subtype, closed: IntervalClosedType) -> None:
#      64         # attributes need to be set first before calling
#      65         # super init (as that calls serialize)
#
# File pyarrow/types.pxi:2226, in pyarrow.lib.register_extension_type()
# -> 2226 'Could not get source, probably due dynamically evaluated source code.'
#
# File pyarrow/error.pxi:92, in pyarrow.lib.check_status()
# ---> 92 'Could not get source, probably due dynamically evaluated source code.'
#
# ArrowKeyError: A type extension with name pandas.period already defined

# %%
#Nessa primeira parte a gente vai basicamente requisitar as tecnologias que iremos utilizar, que no caso seria o pandas para analisar os dados, o request pra requisitar a entrada do site e o bs4 (beautifulsoup) para extrair os dados.

i
